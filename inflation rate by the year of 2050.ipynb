# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('inflation3.csv')

# %%
df
# Out:
#     year  Inflation Rate(percentage%)
# 0   2021                         5.55
# 1   2020                         5.69
# 2   2019                         5.59
# 3   2018                         5.54
# 4   2017                         5.70
# 5   2016                         5.51
# 6   2015                         6.19
# 7   2014                         6.99
# 8   2013                         7.53
# 9   2012                         6.22
# 10  2011                        11.40
# 11  2010                         8.13
# 12  2009                         5.42
# 13  2008                         8.90
# 14  2007                         9.11
# 15  2006                         6.77
# 16  2005                         7.05
# 17  2004                         7.59
# 18  2003                         5.67
# 19  2002                         3.33
# 20  2001                         2.01
# 21  2000                         2.21

# %%
x=df[['year']]

# %%
x
# Out:
#     year
# 0   2021
# 1   2020
# 2   2019
# 3   2018
# 4   2017
# 5   2016
# 6   2015
# 7   2014
# 8   2013
# 9   2012
# 10  2011
# 11  2010
# 12  2009
# 13  2008
# 14  2007
# 15  2006
# 16  2005
# 17  2004
# 18  2003
# 19  2002
# 20  2001
# 21  2000

# %%
y=df[['Inflation Rate(percentage%)']]

# %%
y
# Out:
#     Inflation Rate(percentage%)
# 0                          5.55
# 1                          5.69
# 2                          5.59
# 3                          5.54
# 4                          5.70
# 5                          5.51
# 6                          6.19
# 7                          6.99
# 8                          7.53
# 9                          6.22
# 10                        11.40
# 11                         8.13
# 12                         5.42
# 13                         8.90
# 14                         9.11
# 15                         6.77
# 16                         7.05
# 17                         7.59
# 18                         5.67
# 19                         3.33
# 20                         2.01
# 21                         2.21

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#     year
# 4   2017
# 10  2011
# 20  2001
# 2   2019
# 5   2016
# 15  2006
# 19  2002
# 14  2007
# 17  2004
# 13  2008
# 11  2010
# 21  2000
# 8   2013
# 3   2018
# 18  2003

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [raw]
# reg.predict(x_test)

# %%
reg.predict(x_test)
# Out:
# array([[6.70407078],
#        [7.81828311],
#        [7.69448174],
#        [6.33266667],
#        [5.83746119],
#        [6.95167352],
#        [7.07547489]])

# %%
y_test
# Out:
#     Inflation Rate(percentage%)
# 9                          6.22
# 0                          5.55
# 1                          5.69
# 12                         5.42
# 16                         7.05
# 7                          6.99
# 6                          6.19

# %%
reg.predict([[2050]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[11.40852283]])
